# %%
df = spark.sql("select * from workspace.default.movies where studio= 'Marvel Studios'")
df.show()

# %% [markdown]
# ### To see full unresolved and optimized plan

# %%
df.explain("extended")

# %% [markdown]
# ### to see only Pyshical/Optimized plan

# %%
df.explain("formatted")
